# %% [markdown]
# # Complete GNN–BERT Music Context Pipeline
# This notebook runs the project in the same sequence as the assignment tasks.
#
# **Kaggle:** choose a GPU accelerator and keep only GPU 0 visible.

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
print('Using only CUDA device 0')

# %% [markdown]
# ## Install dependencies

# %%
# !pip install -q -r ../requirements.txt

# %% [markdown]
# ## Prepare data
# Before continuing, make sure `../data/splits/musiccaps.csv` and the corresponding audio files exist.

# %%
# !cd .. && python -m src.preprocess --config config.yaml

# %% [markdown]
# ## CNN baseline

# %%
# !cd .. && python -m src.train_cnn --config config.yaml

# %% [markdown]
# ## Task 1 — BERT baseline

# %%
# !cd .. && python -m src.train --config config.yaml --model bert

# %% [markdown]
# ## Task 2 — GNN baseline

# %%
# !cd .. && python -m src.train --config config.yaml --model gnn

# %% [markdown]
# ## Task 3 — Early concatenation ablation

# %%
# !cd .. && python -m src.train --config config.yaml --model concat

# %% [markdown]
# ## Task 3 — Cross-attention GNN–BERT

# %%
# !cd .. && python -m src.train --config config.yaml --model fusion

# %% [markdown]
# ## Three graph-text case studies

# %%
# !cd .. && python -m src.case_studies --config config.yaml --checkpoint results/fusion/best_model.pt --num-cases 3

# %% [markdown]
# ## Task 4 — Contrastive retrieval

# %%
# !cd .. && python -m src.train_contrastive --config config.yaml

# %% [markdown]
# ## Build final ablation table

# %%
# !cd .. && python scripts/compare_models.py

# %%
import pandas as pd
display(pd.read_csv('../results/ablation_comparison.csv'))
