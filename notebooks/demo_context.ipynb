# %% [markdown]
# # End-to-end GNN–BERT inference demo
# Train the fusion model first, then update `audio_path` and `caption` below.

# %%
import sys
sys.path.append('..')
from src.inference import MusicContextPredictor
predictor = MusicContextPredictor('../config.yaml', '../results/fusion/best_model.pt', 'fusion')

# %%
audio_path = '../data/raw/musiccaps_audio/PUT_TRACK_ID_HERE.wav'
caption = 'A mellow instrumental track with soft piano and gentle rhythm.'
result = predictor.predict(audio_path, caption, threshold=0.5, top_k=10)
result
